# %% [markdown]
# # Exercício da Aula - Pandas (Prática em Python)

# %%
import pandas as pd

# %%
# importando arquivo
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a37fe7b2-ecac-46ff-aaa5-fa0844d7163f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a37fe7b2-ecac-46ff-aaa5-fa0844d7163f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# carrega arquivo para dataframe Pandas
data = pd.read_csv("Credit.csv")
# formato
data.shape
# Out:
# (1000, 21)

# %%
# resumo estatístico de colunas numéricas
data.describe()
# Out:
#           duration  credit_amount  installment_commitment  residence_since  \
# count  1000.000000    1000.000000             1000.000000      1000.000000
# mean     20.903000    3271.258000                2.973000         2.845000
# std      12.058814    2822.736876                1.118715         1.103718
# min       4.000000     250.000000                1.000000         1.000000
# 25%      12.000000    1365.500000                2.000000         2.000000
# 50%      18.000000    2319.500000                3.000000         3.000000
# 75%      24.000000    3972.250000                4.000000         4.000000
# max      72.000000   18424.000000                4.000000         4.000000
#
#                age  existing_credits  num_dependents
# count  1000.000000       1000.000000     1000.000000
# mean     35.546000          1.407000        1.155000
# std      11.375469          0.577654        0.362086
# min      19.000000          1.000000        1.000000
# ...

# %%
# primeiros registros
data.head()
# Out:
#   checking_status  duration                    credit_history  \
# 0              <0         6  'critical/other existing credit'
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
#
#                purpose  credit_amount      savings_status employment  \
# 0             radio/tv           1169  'no known savings'        >=7
# 1             radio/tv           5951                <100     1<=X<4
# 2            education           2096                <100     4<=X<7
# 3  furniture/equipment           7882                <100     4<=X<7
# 4            'new car'           4870                <100     1<=X<4
#
#    installment_commitment       personal_status other_parties  ...  \
# 0                       4         'male single'          none  ...
# ...

# %%
# últimos registros, com parâmetros
data.tail(2)
# Out:
#     checking_status  duration                    credit_history     purpose  \
# 998              <0        45                   'existing paid'    radio/tv
# 999        0<=X<200        45  'critical/other existing credit'  'used car'
#
#      credit_amount savings_status  employment  installment_commitment  \
# 998           1845           <100      1<=X<4                       4
# 999           4576     100<=X<500  unemployed                       3
#
#     personal_status other_parties  ...   property_magnitude age  \
# 998   'male single'          none  ...  'no known property'  23
# 999   'male single'          none  ...                  car  27
#
#      other_payment_plans     housing existing_credits      job num_dependents  \
# 998                 none  'for free'                1  skilled              1
# 999                 none         own                1  skilled              1
#
#      own_telephone foreign_worker class
# 998            yes            yes   bad
# ...

# %%
# filtrando pelo nome da coluna
data[["credit_amount"]]
# Out:
#      credit_amount
# 0             1169
# 1             5951
# 2             2096
# 3             7882
# 4             4870
# ..             ...
# 995           1736
# 996           3857
# 997            804
# 998           1845
# 999           4576
#
# [1000 rows x 1 columns]

# %%
# filtrando linhas por índice
data.loc[1:3]
# Out:
#   checking_status  duration                    credit_history  \
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
#
#                purpose  credit_amount savings_status employment  \
# 1             radio/tv           5951           <100     1<=X<4
# 2            education           2096           <100     4<=X<7
# 3  furniture/equipment           7882           <100     4<=X<7
#
#    installment_commitment       personal_status other_parties  ...  \
# 1                       2  'female div/dep/mar'          none  ...
# 2                       2         'male single'          none  ...
# 3                       2         'male single'     guarantor  ...
#
#    property_magnitude age  other_payment_plans     housing existing_credits  \
# 1       'real estate'  22                 none         own                1
# ...

# %%
# filtrando linhas 1 e 3
data.loc[[1,3]]
# Out:
#   checking_status  duration   credit_history              purpose  \
# 1        0<=X<200        48  'existing paid'             radio/tv
# 3              <0        42  'existing paid'  furniture/equipment
#
#    credit_amount savings_status employment  installment_commitment  \
# 1           5951           <100     1<=X<4                       2
# 3           7882           <100     4<=X<7                       2
#
#         personal_status other_parties  ...  property_magnitude age  \
# 1  'female div/dep/mar'          none  ...       'real estate'  22
# 3         'male single'     guarantor  ...    'life insurance'  45
#
#    other_payment_plans     housing existing_credits      job num_dependents  \
# 1                 none         own                1  skilled              1
# 3                 none  'for free'                1  skilled              2
#
#    own_telephone foreign_worker class
# 1           none            yes   bad
# 3           none            yes  good
#
# ...

# %%
# filtro
data.loc[data["num_dependents"] == 1]
# Out:
#     checking_status  duration                    credit_history  \
# 0                <0         6  'critical/other existing credit'
# 1          0<=X<200        48                   'existing paid'
# 6     'no checking'        24                   'existing paid'
# 7          0<=X<200        36                   'existing paid'
# 8     'no checking'        12                   'existing paid'
# ..              ...       ...                               ...
# 995   'no checking'        12                   'existing paid'
# 996              <0        30                   'existing paid'
# 997   'no checking'        12                   'existing paid'
# 998              <0        45                   'existing paid'
# 999        0<=X<200        45  'critical/other existing credit'
#
#                  purpose  credit_amount      savings_status  employment  \
# 0               radio/tv           1169  'no known savings'         >=7
# ...

# %%
# outra condição
data.loc[data["credit_amount"] < 1000]
# Out:
#     checking_status  duration                    credit_history  \
# 26    'no checking'         6             'no credits/all paid'
# 27            >=200        12                        'all paid'
# 39         0<=X<200         9                   'existing paid'
# 55    'no checking'         6                        'all paid'
# 71    'no checking'         7  'critical/other existing credit'
# ..              ...       ...                               ...
# 936           >=200         9                   'existing paid'
# 942   'no checking'        24                   'existing paid'
# 964        0<=X<200         6                   'existing paid'
# 976        0<=X<200         6                   'existing paid'
# 997   'no checking'        12                   'existing paid'
#
#                  purpose  credit_amount      savings_status employment  \
# 26              radio/tv            426                <100        >=7
# ...

# %%
# atribuindo resultado à uma variável, criando outro dataframe
credit_good_class = data.loc[data["class"] == "good"]
print(credit_good_class)
# Out:
#     checking_status  duration                    credit_history  \
# 0                <0         6  'critical/other existing credit'
# 2     'no checking'        12  'critical/other existing credit'
# 3                <0        42                   'existing paid'
# 5     'no checking'        36                   'existing paid'
# 6     'no checking'        24                   'existing paid'
# ..              ...       ...                               ...
# 994   'no checking'        12                   'existing paid'
# 995   'no checking'        12                   'existing paid'
# 996              <0        30                   'existing paid'
# 997   'no checking'        12                   'existing paid'
# 999        0<=X<200        45  'critical/other existing credit'
#
#                  purpose  credit_amount      savings_status  employment  \
# 0               radio/tv           1169  'no known savings'         >=7
# ...

# %%
# definindo colunas
credit2 = data[["purpose", "credit_amount", "personal_status"]].loc[data["age"] > 50]
print(credit2)
# Out:
#                  purpose  credit_amount       personal_status
# 0               radio/tv           1169         'male single'
# 4              'new car'           4870         'male single'
# 6    furniture/equipment           2835         'male single'
# 8               radio/tv           3059        'male div/sep'
# 13             'new car'           1199         'male single'
# ..                   ...            ...                   ...
# 955             radio/tv           1231  'female div/dep/mar'
# 967             radio/tv           3568  'female div/dep/mar'
# 975             radio/tv           1258  'female div/dep/mar'
# 976             radio/tv            753  'female div/dep/mar'
# 987             radio/tv           1409  'female div/dep/mar'
#
# [113 rows x 3 columns]

# %%
# séries, coluna única
# pode ser criada a partir de listas, arrays do numpy ou coluna de um data frame
s1 = pd.Series([1, 2, 5, 9, 30, 45, 27, 12])
print(s1)
# Out:
# 0     1
# 1     2
# 2     5
# 3     9
# 4    30
# 5    45
# 6    27
# 7    12
# dtype: int64

# %%
# série a partir de um array do numpy
import numpy as np
array_1 = np.array([1, 2, 4, 6, 8, 10, 12, 15, 39])
s2 = pd.Series(array_1)
print(s2)
# Out:
# 0     1
# 1     2
# 2     4
# 3     6
# 4     8
# 5    10
# 6    12
# 7    15
# 8    39
# dtype: int64

# %%
# séries a partir de um data frame
s3 = data["credit_amount"]
print(s3)
type(s3)
# Out:
# 0      1169
# 1      5951
# 2      2096
# 3      7882
# 4      4870
#        ...
# 995    1736
# 996    3857
# 997     804
# 998    1845
# 999    4576
# Name: credit_amount, Length: 1000, dtype: int64
# pandas.core.series.Series

# %%
# diferença para um data frame...
credit_amount = data[["credit_amount"]]
type(credit_amount)
# Out:
# pandas.core.frame.DataFrame

# %%
# renomear
data.rename(columns = {"duration":"duração", "purpose":"propósito"})
# Out:
#     checking_status  duração                    credit_history  \
# 0                <0        6  'critical/other existing credit'
# 1          0<=X<200       48                   'existing paid'
# 2     'no checking'       12  'critical/other existing credit'
# 3                <0       42                   'existing paid'
# 4                <0       24              'delayed previously'
# ..              ...      ...                               ...
# 995   'no checking'       12                   'existing paid'
# 996              <0       30                   'existing paid'
# 997   'no checking'       12                   'existing paid'
# 998              <0       45                   'existing paid'
# 999        0<=X<200       45  'critical/other existing credit'
#
#                propósito  credit_amount      savings_status  employment  \
# 0               radio/tv           1169  'no known savings'         >=7
# ...

# %%
# a alteração não é persistida!
data.head(1)
# Out:
#   checking_status  duration                    credit_history   purpose  \
# 0              <0         6  'critical/other existing credit'  radio/tv
#
#    credit_amount      savings_status employment  installment_commitment  \
# 0           1169  'no known savings'        >=7                       4
#
#   personal_status other_parties  ...  property_magnitude age  \
# 0   'male single'          none  ...       'real estate'  67
#
#    other_payment_plans housing existing_credits      job num_dependents  \
# 0                 none     own                2  skilled              1
#
#    own_telephone foreign_worker class
# 0            yes            yes  good
#
# [1 rows x 21 columns]

# %%
# para persistir
data.rename(columns = {"duration":"duração", "purpose":"propósito"}, inplace = True)

# %%
# verificando renomeação
data.head(1)
# Out:
#   checking_status  duração                    credit_history propósito  \
# 0              <0        6  'critical/other existing credit'  radio/tv
#
#    credit_amount      savings_status employment  installment_commitment  \
# 0           1169  'no known savings'        >=7                       4
#
#   personal_status other_parties  ...  property_magnitude age  \
# 0   'male single'          none  ...       'real estate'  67
#
#    other_payment_plans housing existing_credits      job num_dependents  \
# 0                 none     own                2  skilled              1
#
#    own_telephone foreign_worker class
# 0            yes            yes  good
#
# [1 rows x 21 columns]

# %%
# excluir coluna
# data.drop("checking_status", axis=1, inplace = True)
data.head(1)
# Out:
#    duração                    credit_history propósito  credit_amount  \
# 0        6  'critical/other existing credit'  radio/tv           1169
#
#        savings_status employment  installment_commitment personal_status  \
# 0  'no known savings'        >=7                       4   'male single'
#
#   other_parties  residence_since property_magnitude  age other_payment_plans  \
# 0          none                4      'real estate'   67                none
#
#   housing  existing_credits      job  num_dependents own_telephone  \
# 0     own                 2  skilled               1           yes
#
#   foreign_worker class
# 0            yes  good

# %%
# verificando dados nulos
data.isnull()
# Out:
#      duração  credit_history  propósito  credit_amount  savings_status  \
# 0      False           False      False          False           False
# 1      False           False      False          False           False
# 2      False           False      False          False           False
# 3      False           False      False          False           False
# 4      False           False      False          False           False
# ..       ...             ...        ...            ...             ...
# 995    False           False      False          False           False
# 996    False           False      False          False           False
# 997    False           False      False          False           False
# 998    False           False      False          False           False
# 999    False           False      False          False           False
#
#      employment  installment_commitment  personal_status  other_parties  \
# ...

# %%
# quantidade de dados nulos
data.isnull().sum()
# Out:
# duração                   0
# credit_history            0
# propósito                 0
# credit_amount             0
# savings_status            0
# employment                0
# installment_commitment    0
# personal_status           0
# other_parties             0
# residence_since           0
# property_magnitude        0
# age                       0
# other_payment_plans       0
# housing                   0
# existing_credits          0
# job                       0
# num_dependents            0
# own_telephone             0
# foreign_worker            0
# class                     0
# dtype: int64

# %%
# retirar coluas como NaN
data.dropna()
# Out:
#      duração                    credit_history            propósito  \
# 0          6  'critical/other existing credit'             radio/tv
# 1         48                   'existing paid'             radio/tv
# 2         12  'critical/other existing credit'            education
# 3         42                   'existing paid'  furniture/equipment
# 4         24              'delayed previously'            'new car'
# ..       ...                               ...                  ...
# 995       12                   'existing paid'  furniture/equipment
# 996       30                   'existing paid'           'used car'
# 997       12                   'existing paid'             radio/tv
# 998       45                   'existing paid'             radio/tv
# 999       45  'critical/other existing credit'           'used car'
#
#      credit_amount      savings_status  employment  installment_commitment  \
# ...

# %%
# preenchendo dados faltantes
data["duração"].fillna(0, inplace = True)

# %%
# filtragem com índice
data.iloc[0:3, 0:5]
# Out:
#    duração                    credit_history  propósito  credit_amount  \
# 0        6  'critical/other existing credit'   radio/tv           1169
# 1       48                   'existing paid'   radio/tv           5951
# 2       12  'critical/other existing credit'  education           2096
#
#        savings_status
# 0  'no known savings'
# 1                <100
# 2                <100

# %%
data.iloc[[1, 3, 5, 7], 0:5]
# Out:
#    duração   credit_history            propósito  credit_amount  \
# 1       48  'existing paid'             radio/tv           5951
# 3       42  'existing paid'  furniture/equipment           7882
# 5       36  'existing paid'            education           9055
# 7       36  'existing paid'           'used car'           6948
#
#        savings_status
# 1                <100
# 3                <100
# 5  'no known savings'
# 7                <100
